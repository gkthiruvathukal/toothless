# %%
from PIL import Image, ImageFilter
import numpy as np
import matplotlib
from matplotlib.pyplot import imshow

# %%
# %matplotlib inline
im = Image.open("pythonlogo.jpg")
im2 = im.rotate(20)
imshow(np.asarray(im2))

# %%
im3 = im2.filter(ImageFilter.GaussianBlur(radius=10))

# %%
imshow(np.asarray(im3))
