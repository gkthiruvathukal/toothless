# %%
from PIL import Image
import numpy as np
import matplotlib
from matplotlib.pyplot import imshow

# %%
# %matplotlib inline
im = Image.open("/home/gkt/Downloads/pythonlogo.jpg")
im2 = im.rotate(20)
imshow(np.asarray(im2))
